# %%
import pandas as pd

# %% [markdown]
# #### Reading the Data

# %%
df = pd.read_csv('Dataset/airports.csv')
df.head()
# Out:
#      ID           TYPE                                NAME  LATITUDE  \
# 0  6523       heliport                   Total Rf Heliport        40
# 1  6524  small_airport                        Lowell Field        60
# 2  6525  small_airport                        Epps Airpark        35
# 3  6526       heliport  Newport Hospital & Clinic Heliport        36
# 4  6527  small_airport                      Cordes Airport        34
#
#    LONGITUDE COUNTRY REGION
# 0        -75      US  US-PA
# 1       -152      US  US-AK
# 2        -87      US  US-AL
# 3        -91      US  US-AR
# 4       -112      US  US-AZ

# %% [markdown]
# #### Number of Airports by Country and Country with most Airports

# %%
country = 'US'
country_df = df[df.COUNTRY == country]
country_df.head()
# Out:
#      ID           TYPE                                NAME  LATITUDE  \
# 0  6523       heliport                   Total Rf Heliport        40
# 1  6524  small_airport                        Lowell Field        60
# 2  6525  small_airport                        Epps Airpark        35
# 3  6526       heliport  Newport Hospital & Clinic Heliport        36
# 4  6527  small_airport                      Cordes Airport        34
#
#    LONGITUDE COUNTRY REGION
# 0        -75      US  US-PA
# 1       -152      US  US-AK
# 2        -87      US  US-AL
# 3        -91      US  US-AR
# 4       -112      US  US-AZ

# %%
df['COUNTRY'].value_counts()
# Out:
# US    21403
# BR     3799
# CA     2394
# AU     1725
# RU      910
# FR      782
# CO      700
# AR      699
# VE      592
# DE      548
# CL      464
# GB      452
# ZA      432
# IN      314
# CN      305
# ID      297
# CD      266
# PG      253
# KE      239
# NZ      199
# KR      186
# BO      181
# SE      177
# UZ      174
# MX      173
# ES      170
# PL      168
# PE      162
# NO      159
# IT      154
#       ...
# LC        2
# BN        2
# MS        2
# KN        2
# RE        2
# SM        2
# AI        1
# MC        1
# NR        1
# MQ        1
# TV        1
# GI        1
# AD        1
# GM        1
# LI        1
# MO        1
# NF        1
# IO        1
# NU        1
# CC        1
# JE        1
# BL        1
# CX        1
# CW        1
# YT        1
# VA        1
# SH        1
# SX        1
# AW        1
# MF        1
# Name: COUNTRY, Length: 242, dtype: int64

# %% [markdown]
# #### Latitude and Longitude filters

# %%
cond = df.LATITUDE.between(10, 90) & df.LONGITUDE.between(-90, -10)
filtered_df = df[cond]
# Out:
#      ID           TYPE                 NAME  LATITUDE  LONGITUDE COUNTRY  \
# 0  6523       heliport    Total Rf Heliport        40        -75      US
# 2  6525  small_airport         Epps Airpark        35        -87      US
# 7  6531  small_airport  Grass Patch Airport        29        -82      US
# 8  6532       heliport   Ringhaver Heliport        29        -82      US
# 9  6533  small_airport    River Oak Airport        27        -81      US
#
#   REGION
# 0  US-PA
# 2  US-AL
# 7  US-FL
# 8  US-FL
# 9  US-FL
